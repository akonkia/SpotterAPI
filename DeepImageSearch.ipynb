# %%
# %pip install DeepImageSearch -q

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#https://github.com/TechyNilesh/DeepImageSearch/blob/main/Documents/Document.md
# Importing the proper classes
from DeepImageSearch import Load_Data, Search_Setup

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
import timm
timm.list_models(pretrained=True)

# %%
# load the Images from the Folder (You can also import data from multiple folders in python list type)

dl = Load_Data()

image_list = dl.from_folder(['drive/MyDrive/SpotterQ-thumbs/'])

# %%
image_list

# %%
len(image_list)
# Out:
# 3497

# %%
pwd
# Out:
# '/content'

# %%
# For Faster Serching we need to index Data first, After Indexing all the meta data stored on the local path
#vgg19
st = Search_Setup(image_list, model_name="inception_v4.tf_in1k", pretrained=True, image_count=None)
st.run_index()
# Out:
#  Please Wait Model Is Loading or Downloading From Server!
#  Model Loaded Successfully: inception_v4.tf_in1k
#  Metadata and Features are already present, Do you want Extract Again? Enter yes or no
#  38%|███▊      | 1346/3497 [11:27<13:16,  2.70it/s]/usr/local/lib/python3.10/dist-packages/PIL/TiffImagePlugin.py:858: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# 100%|██████████| 3497/3497 [29:26<00:00,  1.98it/s]
#  Image Meta Information Saved: [metadata-files/inception_v4.tf_in1k/image_data_features.pkl]
#  Saved The Indexed File:[metadata-files/inception_v4.tf_in1k/image_features_vectors.idx]

# %%
image_list[0]
# Out:
# 'drive/MyDrive/SpotterQ-thumbs/20510.jpg'

# %%
st.get_similar_images(image_list[0], number_of_images=6)
# Out:
# {0: 'drive/MyDrive/SpotterQ-thumbs/51935.jpg',
#  2248: 'drive/MyDrive/SpotterQ-thumbs/51279.jpg',
#  999: 'drive/MyDrive/SpotterQ-thumbs/52094.jpg',
#  2408: 'drive/MyDrive/SpotterQ-thumbs/51452.jpg',
#  3054: 'drive/MyDrive/SpotterQ-thumbs/52964.jpg',
#  2612: 'drive/MyDrive/SpotterQ-thumbs/52412.jpg'}

# %%
st.plot_similar_images(image_list[0], number_of_images=6)

# %%
new_image_paths = "/content/71634_1_AP.jpg"

# %%
#Add new images to the existing index.



st.add_images_to_index([new_image_paths])
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  1.09it/s]
#  New images added to the index: 1

# %%
st.plot_similar_images(new_image_paths, number_of_images=4)

# %%
st.get_similar_images(new_image_paths, number_of_images=4)
# Out:
# {3495: '/content/71634_1_AP.jpg',
#  3432: 'drive/MyDrive/SpotterQ-thumbs/71634.jpg',
#  3430: 'drive/MyDrive/SpotterQ-thumbs/71635.jpg',
#  3428: 'drive/MyDrive/SpotterQ-thumbs/71627.jpg'}
